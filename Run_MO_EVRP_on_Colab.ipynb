# %% [markdown]
# # 🚛 Multi-Objective EVRP with Driver Equity - Experiment Runner
#
# This notebook automates the process of running **Driver Equity Experiments** for the EVRPTW Solver.
#
# ## 🚀 Workflow
# 1. **Clone Repository**: Fetch the latest code from GitHub (branch `test07`).
# 2. **Build Project**: Compile C++ code using CMake.
# 3. **Run Experiments**: Execute the bash script to run 3 baselines (Cost-Only, Static, Adaptive).
# 4. **Analyze Results**: Visualize Pareto fronts and convergence.
# 5. **Download Logs**: Zip and download the results folder.

# %%
# 1. Clone Repository
# !git clone https://github.com/N9uyen3n/MO-EVRP-TW.git
# !cd MO-EVRP-TW && git checkout test07 && git pull origin test07

# %%
# 2. Install Dependencies & Build
# !apt-get update && apt-get install -y cmake build-essential

# Build project (all commands chained to ensure proper directory context)
# !cd MO-EVRP-TW && mkdir -p build && cd build && cmake .. -DCMAKE_BUILD_TYPE=Release && make -j4

# Verify build
# !ls -lh MO-EVRP-TW/build/test16 || echo '❌ Build failed! Check errors above.'

# %%
# 3. Run Experiments (This may take a while!)
# Ensure the script has execute permissions
# !chmod +x MO-EVRP-TW/scripts/run_fairness_experiments.sh

# Run the script from the project directory
# !cd MO-EVRP-TW && ./scripts/run_fairness_experiments.sh

# %%
# 4. Quick Analysis (Optional)
import os
import pandas as pd
import matplotlib.pyplot as plt

# Function to read summary logs (you need to implement parsing logic based on your log format)
# For now, let's just list the output files
# !find MO-EVRP-TW/results/fairness_experiments -name "*summary*"

# %%
# 5. Zip and Download Results
# !cd MO-EVRP-TW && zip -r ../fairness_results.zip results/fairness_experiments logs

from google.colab import files
files.download('fairness_results.zip')
